# %%
import os
import pandas as pd
from IPython.display import display

pd.options.display.max_columns = None
data = pd.read_csv('../data/raw/games-features.csv')

# %%
print(data.describe(include='all'))
# Out:
#               QueryID     ResponseID        QueryName          ResponseName  \
# count    13357.000000   13357.000000            13356                 13357
# unique            NaN            NaN            13283                 13199
# top               NaN            NaN  Train Simulator  Train Simulator 2016
# freq              NaN            NaN                5                     9
# mean    353637.916149  353471.814030              NaN                   NaN
# std     146988.380337  147085.351999              NaN                   NaN
# min         10.000000      10.000000              NaN                   NaN
# 25%     282860.000000  282640.000000              NaN                   NaN
# 50%     374040.000000  373870.000000              NaN                   NaN
# 75%     465920.000000  465860.000000              NaN                   NaN
# max     568150.000000  568150.000000              NaN                   NaN
#
#         ReleaseDate   RequiredAge     DemoCount  DeveloperCount      DLCCount  \
# count         13357  13357.000000  13357.000000    13357.000000  13357.000000
# unique         2117           NaN           NaN             NaN           NaN
# top     Aug 22 2016           NaN           NaN             NaN           NaN
# freq            241           NaN           NaN             NaN           NaN
# mean            NaN      0.837688      0.089541        1.032492      0.805944
# std             NaN      3.625701      0.286058        0.437113     10.034901
# min             NaN      0.000000      0.000000        0.000000      0.000000
# 25%             NaN      0.000000      0.000000        1.000000      0.000000
# 50%             NaN      0.000000      0.000000        1.000000      0.000000
# 75%             NaN      0.000000      0.000000        1.000000      0.000000
# max             NaN     18.000000      2.000000       12.000000    630.000000
#
#           Metacritic    MovieCount  PackageCount  RecommendationCount  \
# count   13357.000000  13357.000000  13357.000000         1.335700e+04
# unique           NaN           NaN           NaN                  NaN
# top              NaN           NaN           NaN                  NaN
# freq             NaN           NaN           NaN                  NaN
# mean       12.285319      1.321255      1.088418         1.180463e+03
# std        27.510876      1.178400      0.855219         1.517606e+04
# min         0.000000      0.000000      0.000000         0.000000e+00
# 25%         0.000000      1.000000      1.000000         0.000000e+00
# 50%         0.000000      1.000000      1.000000         0.000000e+00
# 75%         0.000000      2.000000      1.000000         2.430000e+02
# max        96.000000     20.000000     18.000000         1.427633e+06
#
#         PublisherCount  ScreenshotCount  SteamSpyOwners  \
# count     13357.000000     13357.000000    1.335700e+04
# unique             NaN              NaN             NaN
# top                NaN              NaN             NaN
# freq               NaN              NaN             NaN
# mean          0.989668         9.561204    1.668493e+05
# std           0.336972         6.442893    1.127122e+06
# min           0.000000         0.000000    0.000000e+00
# 25%           1.000000         6.000000    8.970000e+02
# 50%           1.000000         8.000000    9.506000e+03
# 75%           1.000000        12.000000    6.044100e+04
# max           4.000000       114.000000    9.068758e+07
#
#         SteamSpyOwnersVariance  SteamSpyPlayersEstimate  \
# count             13357.000000             1.335700e+04
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean               5486.408550             1.081638e+05
# std                9044.093874             1.006635e+06
# min                   0.000000             0.000000e+00
# 25%                 906.000000             5.370000e+02
# 50%                2551.000000             4.125000e+03
# 75%                6434.000000             2.815800e+04
# max              215972.000000             9.068758e+07
#
#         SteamSpyPlayersVariance  AchievementCount  \
# count              13357.000000      13357.000000
# unique                      NaN               NaN
# top                         NaN               NaN
# freq                        NaN               NaN
# mean                4082.329490         14.434678
# std                 7454.869744         41.467021
# min                    0.000000          0.000000
# 25%                  745.000000          0.000000
# 50%                 1717.000000          0.000000
# 75%                 4392.000000         20.000000
# max               215972.000000       1629.000000
#
#         AchievementHighlightedCount ControllerSupport IsFree FreeVerAvail  \
# count                  13357.000000             13357  13357        13357
# unique                          NaN                 2      2            2
# top                             NaN             False  False        False
# freq                            NaN              9699  12312        13270
# mean                       4.170098               NaN    NaN          NaN
# std                        4.831106               NaN    NaN          NaN
# min                        0.000000               NaN    NaN          NaN
# 25%                        0.000000               NaN    NaN          NaN
# 50%                        0.000000               NaN    NaN          NaN
# 75%                       10.000000               NaN    NaN          NaN
# max                       10.000000               NaN    NaN          NaN
#
#        PurchaseAvail SubscriptionAvail PlatformWindows PlatformLinux  \
# count          13357             13357           13357         13357
# unique             2                 2               2             2
# top             True             False            True         False
# freq           10827             13337           13355         10300
# mean             NaN               NaN             NaN           NaN
# std              NaN               NaN             NaN           NaN
# min              NaN               NaN             NaN           NaN
# 25%              NaN               NaN             NaN           NaN
# 50%              NaN               NaN             NaN           NaN
# 75%              NaN               NaN             NaN           NaN
# max              NaN               NaN             NaN           NaN
#
#        PlatformMac PCReqsHaveMin PCReqsHaveRec LinuxReqsHaveMin  \
# count        13357         13357         13357            13357
# unique           2             2             2                2
# top          False          True         False            False
# freq          8795         12629          7555            10293
# mean           NaN           NaN           NaN              NaN
# std            NaN           NaN           NaN              NaN
# min            NaN           NaN           NaN              NaN
# 25%            NaN           NaN           NaN              NaN
# 50%            NaN           NaN           NaN              NaN
# 75%            NaN           NaN           NaN              NaN
# max            NaN           NaN           NaN              NaN
#
#        LinuxReqsHaveRec MacReqsHaveMin MacReqsHaveRec CategorySinglePlayer  \
# count             13357          13357          13357                13357
# unique                2              2              2                    2
# top               False          False          False                 True
# freq              12151           8725          11619                11687
# mean                NaN            NaN            NaN                  NaN
# std                 NaN            NaN            NaN                  NaN
# min                 NaN            NaN            NaN                  NaN
# 25%                 NaN            NaN            NaN                  NaN
# 50%                 NaN            NaN            NaN                  NaN
# 75%                 NaN            NaN            NaN                  NaN
# max                 NaN            NaN            NaN                  NaN
#
#        CategoryMultiplayer CategoryCoop CategoryMMO CategoryInAppPurchase  \
# count                13357        13357       13357                 13357
# unique                   2            2           2                     2
# top                  False        False       False                 False
# freq                  9876        12023       13034                 13184
# mean                   NaN          NaN         NaN                   NaN
# std                    NaN          NaN         NaN                   NaN
# min                    NaN          NaN         NaN                   NaN
# 25%                    NaN          NaN         NaN                   NaN
# 50%                    NaN          NaN         NaN                   NaN
# 75%                    NaN          NaN         NaN                   NaN
# max                    NaN          NaN         NaN                   NaN
#
#        CategoryIncludeSrcSDK CategoryIncludeLevelEditor CategoryVRSupport  \
# count                  13357                      13357             13357
# unique                     2                          2                 2
# top                    False                      False             False
# freq                   13330                      12723             13120
# mean                     NaN                        NaN               NaN
# std                      NaN                        NaN               NaN
# min                      NaN                        NaN               NaN
# 25%                      NaN                        NaN               NaN
# 50%                      NaN                        NaN               NaN
# 75%                      NaN                        NaN               NaN
# max                      NaN                        NaN               NaN
#
#        GenreIsNonGame GenreIsIndie GenreIsAction GenreIsAdventure  \
# count           13357        13357         13357            13357
# unique              2            2             2                2
# top             False         True         False            False
# freq            13038         7780          7724             9038
# mean              NaN          NaN           NaN              NaN
# std               NaN          NaN           NaN              NaN
# min               NaN          NaN           NaN              NaN
# 25%               NaN          NaN           NaN              NaN
# 50%               NaN          NaN           NaN              NaN
# 75%               NaN          NaN           NaN              NaN
# max               NaN          NaN           NaN              NaN
#
#        GenreIsCasual GenreIsStrategy GenreIsRPG GenreIsSimulation  \
# count          13357           13357      13357             13357
# unique             2               2          2                 2
# top            False           False      False             False
# freq            9793           10734      11270             11255
# mean             NaN             NaN        NaN               NaN
# std              NaN             NaN        NaN               NaN
# min              NaN             NaN        NaN               NaN
# 25%              NaN             NaN        NaN               NaN
# 50%              NaN             NaN        NaN               NaN
# 75%              NaN             NaN        NaN               NaN
# max              NaN             NaN        NaN               NaN
#
#        GenreIsEarlyAccess GenreIsFreeToPlay GenreIsSports GenreIsRacing  \
# count               13357             13357         13357         13357
# unique                  2                 2             2             2
# top                 False             False         False         False
# freq                11887             12692         12816         12881
# mean                  NaN               NaN           NaN           NaN
# std                   NaN               NaN           NaN           NaN
# min                   NaN               NaN           NaN           NaN
# 25%                   NaN               NaN           NaN           NaN
# 50%                   NaN               NaN           NaN           NaN
# 75%                   NaN               NaN           NaN           NaN
# max                   NaN               NaN           NaN           NaN
#
#        GenreIsMassivelyMultiplayer PriceCurrency  PriceInitial    PriceFinal  \
# count                        13357         13357  13357.000000  13357.000000
# unique                           2             2           NaN           NaN
# top                          False           USD           NaN           NaN
# freq                         12968         10739           NaN           NaN
# mean                           NaN           NaN      9.155717      8.798596
# std                            NaN           NaN     14.345029     13.606061
# min                            NaN           NaN      0.000000      0.000000
# 25%                            NaN           NaN      1.990000      1.990000
# 50%                            NaN           NaN      5.990000      5.990000
# 75%                            NaN           NaN      9.990000      9.990000
# max                            NaN           NaN    449.990000    449.990000
#
#        SupportEmail SupportURL AboutText Background ShortDescrip  \
# count         13355      13356     13357      13357        13357
# unique         6139       5602     12537      12508        11415
# top
# freq           3518       5204       662        701         1862
# mean            NaN        NaN       NaN        NaN          NaN
# std             NaN        NaN       NaN        NaN          NaN
# min             NaN        NaN       NaN        NaN          NaN
# 25%             NaN        NaN       NaN        NaN          NaN
# 50%             NaN        NaN       NaN        NaN          NaN
# 75%             NaN        NaN       NaN        NaN          NaN
# max             NaN        NaN       NaN        NaN          NaN
#
#        DetailedDescrip DRMNotice ExtUserAcctNotice  \
# count            13357     13357             13357
# unique           12543        45                98
# top
# freq               658     13272             13202
# mean               NaN       NaN               NaN
# std                NaN       NaN               NaN
# min                NaN       NaN               NaN
# 25%                NaN       NaN               NaN
# 50%                NaN       NaN               NaN
# 75%                NaN       NaN               NaN
# max                NaN       NaN               NaN
#
#                                               HeaderImage LegalNotice Reviews  \
# count                                               13357       13356   13357
# unique                                              13175        4702    3282
# top     http://cdn.akamai.steamstatic.com/steam/apps/4...
# freq                                                   15        7812   10043
# mean                                                  NaN         NaN     NaN
# std                                                   NaN         NaN     NaN
# min                                                   NaN         NaN     NaN
# 25%                                                   NaN         NaN     NaN
# 50%                                                   NaN         NaN     NaN
# 75%                                                   NaN         NaN     NaN
# max                                                   NaN         NaN     NaN
#
#                                 SupportedLanguages Website PCMinReqsText  \
# count                                        13357   13357         13357
# unique                                        2381    8767         11570
# top     English**languages with full audio support    None
# freq                                          4100    3161           728
# mean                                           NaN     NaN           NaN
# std                                            NaN     NaN           NaN
# min                                            NaN     NaN           NaN
# 25%                                            NaN     NaN           NaN
# 50%                                            NaN     NaN           NaN
# 75%                                            NaN     NaN           NaN
# max                                            NaN     NaN           NaN
#
#        PCRecReqsText LinuxMinReqsText LinuxRecReqsText MacMinReqsText  \
# count          13357            13357            13357          13357
# unique          5348             2739             1045           4180
# top
# freq            7555            10293            12151           8725
# mean             NaN              NaN              NaN            NaN
# std              NaN              NaN              NaN            NaN
# min              NaN              NaN              NaN            NaN
# 25%              NaN              NaN              NaN            NaN
# 50%              NaN              NaN              NaN            NaN
# 75%              NaN              NaN              NaN            NaN
# max              NaN              NaN              NaN            NaN
#
#        MacRecReqsText
# count           13357
# unique           1558
# top
# freq            11619
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13357 entries, 0 to 13356
# Data columns (total 78 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   QueryID                      13357 non-null  int64
#  1   ResponseID                   13357 non-null  int64
#  2   QueryName                    13356 non-null  object
#  3   ResponseName                 13357 non-null  object
#  4   ReleaseDate                  13357 non-null  object
#  5   RequiredAge                  13357 non-null  int64
#  6   DemoCount                    13357 non-null  int64
#  7   DeveloperCount               13357 non-null  int64
#  8   DLCCount                     13357 non-null  int64
#  9   Metacritic                   13357 non-null  int64
#  10  MovieCount                   13357 non-null  int64
#  11  PackageCount                 13357 non-null  int64
#  12  RecommendationCount          13357 non-null  int64
#  13  PublisherCount               13357 non-null  int64
#  14  ScreenshotCount              13357 non-null  int64
#  15  SteamSpyOwners               13357 non-null  int64
#  16  SteamSpyOwnersVariance       13357 non-null  int64
#  17  SteamSpyPlayersEstimate      13357 non-null  int64
#  18  SteamSpyPlayersVariance      13357 non-null  int64
#  19  AchievementCount             13357 non-null  int64
#  20  AchievementHighlightedCount  13357 non-null  int64
#  21  ControllerSupport            13357 non-null  bool
#  22  IsFree                       13357 non-null  bool
#  23  FreeVerAvail                 13357 non-null  bool
#  24  PurchaseAvail                13357 non-null  bool
#  25  SubscriptionAvail            13357 non-null  bool
#  26  PlatformWindows              13357 non-null  bool
#  27  PlatformLinux                13357 non-null  bool
#  28  PlatformMac                  13357 non-null  bool
#  29  PCReqsHaveMin                13357 non-null  bool
#  30  PCReqsHaveRec                13357 non-null  bool
#  31  LinuxReqsHaveMin             13357 non-null  bool
#  32  LinuxReqsHaveRec             13357 non-null  bool
#  33  MacReqsHaveMin               13357 non-null  bool
#  34  MacReqsHaveRec               13357 non-null  bool
#  35  CategorySinglePlayer         13357 non-null  bool
#  36  CategoryMultiplayer          13357 non-null  bool
#  37  CategoryCoop                 13357 non-null  bool
#  38  CategoryMMO                  13357 non-null  bool
#  39  CategoryInAppPurchase        13357 non-null  bool
#  40  CategoryIncludeSrcSDK        13357 non-null  bool
#  41  CategoryIncludeLevelEditor   13357 non-null  bool
#  42  CategoryVRSupport            13357 non-null  bool
#  43  GenreIsNonGame               13357 non-null  bool
#  44  GenreIsIndie                 13357 non-null  bool
#  45  GenreIsAction                13357 non-null  bool
#  46  GenreIsAdventure             13357 non-null  bool
#  47  GenreIsCasual                13357 non-null  bool
#  48  GenreIsStrategy              13357 non-null  bool
#  49  GenreIsRPG                   13357 non-null  bool
#  50  GenreIsSimulation            13357 non-null  bool
#  51  GenreIsEarlyAccess           13357 non-null  bool
#  52  GenreIsFreeToPlay            13357 non-null  bool
#  53  GenreIsSports                13357 non-null  bool
#  54  GenreIsRacing                13357 non-null  bool
#  55  GenreIsMassivelyMultiplayer  13357 non-null  bool
#  56  PriceCurrency                13357 non-null  object
#  57  PriceInitial                 13357 non-null  float64
#  58  PriceFinal                   13357 non-null  float64
#  59  SupportEmail                 13355 non-null  object
#  60  SupportURL                   13356 non-null  object
#  61  AboutText                    13357 non-null  object
#  62  Background                   13357 non-null  object
#  63  ShortDescrip                 13357 non-null  object
#  64  DetailedDescrip              13357 non-null  object
#  65  DRMNotice                    13357 non-null  object
#  66  ExtUserAcctNotice            13357 non-null  object
#  67  HeaderImage                  13357 non-null  object
#  68  LegalNotice                  13356 non-null  object
#  69  Reviews                      13357 non-null  object
#  70  SupportedLanguages           13357 non-null  object
#  71  Website                      13357 non-null  object
#  72  PCMinReqsText                13357 non-null  object
#  73  PCRecReqsText                13357 non-null  object
#  74  LinuxMinReqsText             13357 non-null  object
#  75  LinuxRecReqsText             13357 non-null  object
#  76  MacMinReqsText               13357 non-null  object
#  77  MacRecReqsText               13357 non-null  object
# dtypes: bool(35), float64(2), int64(18), object(23)
# memory usage: 4.8+ MB
# None

# %%
#Confirm that each ResponseID is unique and doesn't map to more than one game
print(data.groupby(by='ResponseID').agg({'ResponseName':'nunique'}).max())
# Out:
# ResponseName    1
# dtype: int64

# %%
#Drop duplicates based on ResponseID
data.drop_duplicates(subset='ResponseID',inplace=True)
#Drop some fields that won't be helpful
data.drop(columns=['QueryID','QueryName','SupportEmail','SupportURL','PCMinReqsText','PCRecReqsText','LinuxMinReqsText','LinuxRecReqsText','MacMinReqsText','MacRecReqsText'],inplace=True)

# %%
#See if games have only 1 genre.  Looks like most have multiple genres
print(data.iloc[:,(data.columns.get_loc('GenreIsNonGame')):(data.columns.get_loc('GenreIsMassivelyMultiplayer')+1)].columns)
data['NumGenres'] = data.iloc[:,(data.columns.get_loc('GenreIsNonGame')):(data.columns.get_loc('GenreIsMassivelyMultiplayer')+1)].sum(axis=1)
print(data['NumGenres'].value_counts())

#See if any NonGame genre items also have other genres
print(data[data['GenreIsNonGame']]['NumGenres'].value_counts())

#Look at the ones that have another genre marked.  Only other genre that is sometimes marked is early access
print(data[(data['GenreIsNonGame']) & (data['NumGenres']==2)].\
      iloc[:,(data.columns.get_loc('GenreIsNonGame')):(data.columns.get_loc('GenreIsMassivelyMultiplayer')+1)])

#Drop non-games.  Explore early access category later, see if it's somehow possible to link existence of early access
#version to later success of full version (if that's how it works).  However this will likely exceed scope of this project
data = data[~data['GenreIsNonGame']]
print(data['GenreIsNonGame'].value_counts())
data.drop(columns='GenreIsNonGame',inplace=True)
print(data.columns)
# Out:
# Index(['GenreIsNonGame', 'GenreIsIndie', 'GenreIsAction', 'GenreIsAdventure',
#        'GenreIsCasual', 'GenreIsStrategy', 'GenreIsRPG', 'GenreIsSimulation',
#        'GenreIsEarlyAccess', 'GenreIsFreeToPlay', 'GenreIsSports',
#        'GenreIsRacing', 'GenreIsMassivelyMultiplayer'],
#       dtype='object')
# 2     3974
# 3     3253
# 1     2745
# 4     1587
# 0      739
# 5      615
# 6      212
# 7       63
# 8       17
# 10       2
# 9        1
# Name: NumGenres, dtype: int64
# 1    286
# 2     32
# Name: NumGenres, dtype: int64
#        GenreIsNonGame  GenreIsIndie  GenreIsAction  GenreIsAdventure  \
# 4805             True         False          False             False
# 5592             True         False          False             False
# 5833             True         False          False             False
# 6438             True         False          False             False
# 7437             True         False          False             False
# 8628             True         False          False             False
# 9230             True         False          False             False
# 9314             True         False          False             False
# 9525             True         False          False             False
# 9580             True         False          False             False
# 9858             True         False          False             False
# 10063            True         False          False             False
# 10264            True         False          False             False
# 10863            True         False          False             False
# 10919            True         False          False             False
# 11014            True         False          False             False
# 11143            True         False          False             False
# 11451            True         False          False             False
# 11562            True         False          False             False
# 11568            True         False          False             False
# 11766            True         False          False             False
# 11774            True         False          False             False
# 11919            True         False          False             False
# 12010            True         False          False             False
# 12109            True         False          False             False
# 12171            True         False          False             False
# 12203            True         False          False             False
# 12619            True         False          False             False
# 12665            True         False          False             False
# 12745            True         False          False             False
# 13087            True         False          False             False
# 13278            True         False          False             False
#
#        GenreIsCasual  GenreIsStrategy  GenreIsRPG  GenreIsSimulation  \
# 4805           False            False       False              False
# 5592           False            False       False              False
# 5833           False            False       False              False
# 6438           False            False       False              False
# 7437           False            False       False              False
# 8628           False            False       False              False
# 9230           False            False       False              False
# 9314           False            False       False              False
# 9525           False            False       False              False
# 9580           False            False       False              False
# 9858           False            False       False              False
# 10063          False            False       False              False
# 10264          False            False       False              False
# 10863          False            False       False              False
# 10919          False            False       False              False
# 11014          False            False       False              False
# 11143          False            False       False              False
# 11451          False            False       False              False
# 11562          False            False       False              False
# 11568          False            False       False              False
# 11766          False            False       False              False
# 11774          False            False       False              False
# 11919          False            False       False              False
# 12010          False            False       False              False
# 12109          False            False       False              False
# 12171          False            False       False              False
# 12203          False            False       False              False
# 12619          False            False       False              False
# 12665          False            False       False              False
# 12745          False            False       False              False
# 13087          False            False       False              False
# 13278          False            False       False              False
#
#        GenreIsEarlyAccess  GenreIsFreeToPlay  GenreIsSports  GenreIsRacing  \
# 4805                 True              False          False          False
# 5592                 True              False          False          False
# 5833                 True              False          False          False
# 6438                 True              False          False          False
# 7437                 True              False          False          False
# 8628                 True              False          False          False
# 9230                 True              False          False          False
# 9314                 True              False          False          False
# 9525                 True              False          False          False
# 9580                 True              False          False          False
# 9858                 True              False          False          False
# 10063                True              False          False          False
# 10264                True              False          False          False
# 10863                True              False          False          False
# 10919                True              False          False          False
# 11014                True              False          False          False
# 11143                True              False          False          False
# 11451                True              False          False          False
# 11562                True              False          False          False
# 11568                True              False          False          False
# 11766                True              False          False          False
# 11774                True              False          False          False
# 11919                True              False          False          False
# 12010                True              False          False          False
# 12109                True              False          False          False
# 12171                True              False          False          False
# 12203                True              False          False          False
# 12619                True              False          False          False
# 12665                True              False          False          False
# 12745                True              False          False          False
# 13087                True              False          False          False
# 13278                True              False          False          False
#
#        GenreIsMassivelyMultiplayer
# 4805                         False
# 5592                         False
# 5833                         False
# 6438                         False
# 7437                         False
# 8628                         False
# 9230                         False
# 9314                         False
# 9525                         False
# 9580                         False
# 9858                         False
# 10063                        False
# 10264                        False
# 10863                        False
# 10919                        False
# 11014                        False
# 11143                        False
# 11451                        False
# 11562                        False
# 11568                        False
# 11766                        False
# 11774                        False
# 11919                        False
# 12010                        False
# 12109                        False
# 12171                        False
# 12203                        False
# 12619                        False
# 12665                        False
# 12745                        False
# 13087                        False
# 13278                        False
# False    12890
# Name: GenreIsNonGame, dtype: int64
# Index(['ResponseID', 'ResponseName', 'ReleaseDate', 'RequiredAge', 'DemoCount',
#        'DeveloperCount', 'DLCCount', 'Metacritic', 'MovieCount',
#        'PackageCount', 'RecommendationCount', 'PublisherCount',
#        'ScreenshotCount', 'SteamSpyOwners', 'SteamSpyOwnersVariance',
#        'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance',
#        'AchievementCount', 'AchievementHighlightedCount', 'ControllerSupport',
#        'IsFree', 'FreeVerAvail', 'PurchaseAvail', 'SubscriptionAvail',
#        'PlatformWindows', 'PlatformLinux', 'PlatformMac', 'PCReqsHaveMin',
#        'PCReqsHaveRec', 'LinuxReqsHaveMin', 'LinuxReqsHaveRec',
#        'MacReqsHaveMin', 'MacReqsHaveRec', 'CategorySinglePlayer',
#        'CategoryMultiplayer', 'CategoryCoop', 'CategoryMMO',
#        'CategoryInAppPurchase', 'CategoryIncludeSrcSDK',
#        'CategoryIncludeLevelEditor', 'CategoryVRSupport', 'GenreIsIndie',
#        'GenreIsAction', 'GenreIsAdventure', 'GenreIsCasual', 'GenreIsStrategy',
#        'GenreIsRPG', 'GenreIsSimulation', 'GenreIsEarlyAccess',
#        'GenreIsFreeToPlay', 'GenreIsSports', 'GenreIsRacing',
#        'GenreIsMassivelyMultiplayer', 'PriceCurrency', 'PriceInitial',
#        'PriceFinal', 'AboutText', 'Background', 'ShortDescrip',
#        'DetailedDescrip', 'DRMNotice', 'ExtUserAcctNotice', 'HeaderImage',
#        'LegalNotice', 'Reviews', 'SupportedLanguages', 'Website', 'NumGenres'],
#       dtype='object')

# %%
#Re-check for missing values
print(data.isnull().describe())
# Out:
#        ResponseID ResponseName ReleaseDate RequiredAge DemoCount  \
# count       12890        12890       12890       12890     12890
# unique          1            1           1           1         1
# top         False        False       False       False     False
# freq        12890        12890       12890       12890     12890
#
#        DeveloperCount DLCCount Metacritic MovieCount PackageCount  \
# count           12890    12890      12890      12890        12890
# unique              1        1          1          1            1
# top             False    False      False      False        False
# freq            12890    12890      12890      12890        12890
#
#        RecommendationCount PublisherCount ScreenshotCount SteamSpyOwners  \
# count                12890          12890           12890          12890
# unique                   1              1               1              1
# top                  False          False           False          False
# freq                 12890          12890           12890          12890
#
#        SteamSpyOwnersVariance SteamSpyPlayersEstimate SteamSpyPlayersVariance  \
# count                   12890                   12890                   12890
# unique                      1                       1                       1
# top                     False                   False                   False
# freq                    12890                   12890                   12890
#
#        AchievementCount AchievementHighlightedCount ControllerSupport IsFree  \
# count             12890                       12890             12890  12890
# unique                1                           1                 1      1
# top               False                       False             False  False
# freq              12890                       12890             12890  12890
#
#        FreeVerAvail PurchaseAvail SubscriptionAvail PlatformWindows  \
# count         12890         12890             12890           12890
# unique            1             1                 1               1
# top           False         False             False           False
# freq          12890         12890             12890           12890
#
#        PlatformLinux PlatformMac PCReqsHaveMin PCReqsHaveRec LinuxReqsHaveMin  \
# count          12890       12890         12890         12890            12890
# unique             1           1             1             1                1
# top            False       False         False         False            False
# freq           12890       12890         12890         12890            12890
#
#        LinuxReqsHaveRec MacReqsHaveMin MacReqsHaveRec CategorySinglePlayer  \
# count             12890          12890          12890                12890
# unique                1              1              1                    1
# top               False          False          False                False
# freq              12890          12890          12890                12890
#
#        CategoryMultiplayer CategoryCoop CategoryMMO CategoryInAppPurchase  \
# count                12890        12890       12890                 12890
# unique                   1            1           1                     1
# top                  False        False       False                 False
# freq                 12890        12890       12890                 12890
#
#        CategoryIncludeSrcSDK CategoryIncludeLevelEditor CategoryVRSupport  \
# count                  12890                      12890             12890
# unique                     1                          1                 1
# top                    False                      False             False
# freq                   12890                      12890             12890
#
#        GenreIsIndie GenreIsAction GenreIsAdventure GenreIsCasual  \
# count         12890         12890            12890         12890
# unique            1             1                1             1
# top           False         False            False         False
# freq          12890         12890            12890         12890
#
#        GenreIsStrategy GenreIsRPG GenreIsSimulation GenreIsEarlyAccess  \
# count            12890      12890             12890              12890
# unique               1          1                 1                  1
# top              False      False             False              False
# freq             12890      12890             12890              12890
#
#        GenreIsFreeToPlay GenreIsSports GenreIsRacing  \
# count              12890         12890         12890
# unique                 1             1             1
# top                False         False         False
# freq               12890         12890         12890
#
#        GenreIsMassivelyMultiplayer PriceCurrency PriceInitial PriceFinal  \
# count                        12890         12890        12890      12890
# unique                           1             1            1          1
# top                          False         False        False      False
# freq                         12890         12890        12890      12890
#
#        AboutText Background ShortDescrip DetailedDescrip DRMNotice  \
# count      12890      12890        12890           12890     12890
# unique         1          1            1               1         1
# top        False      False        False           False     False
# freq       12890      12890        12890           12890     12890
#
#        ExtUserAcctNotice HeaderImage LegalNotice Reviews SupportedLanguages  \
# count              12890       12890       12890   12890              12890
# unique                 1           1           2       1                  1
# top                False       False       False   False              False
# freq               12890       12890       12889   12890              12890
#
#        Website NumGenres
# count    12890     12890
# unique       1         1
# top      False     False
# freq     12890     12890

# %%
import numpy as np

#Looks good, just one missing legal notice. Will change from NaN to None after EDA in next workbook,
#since None more compatible with Tableau
#data['LegalNotice'] = data['LegalNotice'].replace({np.nan:None})
print(data[data['LegalNotice'].isnull()]['LegalNotice'])
# Out:
# 5326    NaN
# Name: LegalNotice, dtype: object

# %%
#However, many zeroes are actually missing values. Will replace with np.nan for now, and with None after EDA
columns = ['DeveloperCount','Metacritic','PublisherCount','SteamSpyOwners','SteamSpyOwnersVariance','SteamSpyPlayersEstimate','SteamSpyPlayersVariance']
data[columns] = data[columns].replace(0, np.nan)

# %%
#Remove rows without SteamSpy data. I suspect we will primarily focus on owners rather than estimated players since 2009,
#so will delete only where Owners is null, leaving some rows where Players is null
print(data['SteamSpyOwners'].isnull().sum())
print(data['SteamSpyPlayersEstimate'].isnull().sum())
print(data.shape)
data = data[~data['SteamSpyOwners'].isnull()]
print(data.shape)
# Out:
# 2596
# 2838
# (12890, 68)
# (10294, 68)

# %%
#Convert dates to datetime objects
print(data['ReleaseDate'].head(20))
data['ReleaseDate'] = pd.to_datetime(data['ReleaseDate'],errors='coerce',format='%b %d %Y')
print(data['ReleaseDate'].head(20))
# Out:
# 0      Nov 1 2000
# 1      Apr 1 1999
# 2      May 1 2003
# 3      Jun 1 2001
# 4      Nov 1 1999
# 5      Nov 1 2000
# 6      Nov 8 1998
# 7      Mar 1 2004
# 9      Jun 1 2001
# 10    Nov 16 2004
# 11     Nov 1 2004
# 12     Jun 1 2004
# 13    Jul 12 2010
# 14     Nov 1 2004
# 15    Oct 27 2005
# 16     May 1 2006
# 17     Jun 1 2006
# 18    Oct 10 2007
# 19    Oct 10 2007
# 20    Oct 10 2007
# Name: ReleaseDate, dtype: object
# 0    2000-11-01
# 1    1999-04-01
# 2    2003-05-01
# 3    2001-06-01
# 4    1999-11-01
# 5    2000-11-01
# 6    1998-11-08
# 7    2004-03-01
# 9    2001-06-01
# 10   2004-11-16
# 11   2004-11-01
# 12   2004-06-01
# 13   2010-07-12
# 14   2004-11-01
# 15   2005-10-27
# 16   2006-05-01
# 17   2006-06-01
# 18   2007-10-10
# 19   2007-10-10
# 20   2007-10-10
# Name: ReleaseDate, dtype: datetime64[ns]

# %%
#Will convert NaTs to None after EDA
#print(data['ReleaseDate'].isnull().sum())
#print(data.loc[data['ReleaseDate'].isnull(),['ReleaseDate']])
#data['ReleaseDate'] = data['ReleaseDate'].astype(object).where(data['ReleaseDate'].notnull(),None)
#print(data.loc[data['ReleaseDate'].isnull(),['ReleaseDate']])

# %%
#One-hot encode languages column
data['SupportedLanguages'] = data['SupportedLanguages'].str.replace('*',' ')
data['SupportedLanguages'] = data['SupportedLanguages'].str.replace('Simplified ','Simplified*')
data['SupportedLanguages'] = data['SupportedLanguages'].str.replace('Traditional ','Traditional*')
from collections import Counter
Counter(" ".join(data['SupportedLanguages']).split()).most_common(100)
# Out:
# C:\Users\eagra\AppData\Local\Temp/ipykernel_31056/3879787722.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['SupportedLanguages'] = data['SupportedLanguages'].str.replace('*',' ')
# [('English', 10246),
#  ('with', 4952),
#  ('full', 4952),
#  ('audio', 4952),
#  ('support', 4951),
#  ('languages', 4949),
#  ('German', 3387),
#  ('French', 3185),
#  ('Spanish', 2870),
#  ('Italian', 2439),
#  ('Russian', 2269),
#  ('Japanese', 1150),
#  ('Polish', 1123),
#  ('Portuguese-Brazil', 954),
#  ('Simplified*Chinese', 683),
#  ('Dutch', 588),
#  ('Korean', 546),
#  ('Portuguese', 537),
#  ('Czech', 444),
#  ('Traditional*Chinese', 416),
#  ('Turkish', 339),
#  ('Swedish', 305),
#  ('Hungarian', 268),
#  ('Danish', 211),
#  ('Norwegian', 180),
#  ('Finnish', 168),
#  ('Ukrainian', 156),
#  ('Greek', 103),
#  ('Romanian', 100),
#  ('Arabic', 87),
#  ('Thai', 82),
#  ('Bulgarian', 80),
#  ('[/b]', 5),
#  ('English[b]', 3),
#  ('Slovakian', 2),
#  ('German;', 2),
#  ('[/b]languages', 2),
#  ('HungarianPolish', 1),
#  ('RussianEnglishSpanishFrenchJapaneseCzech', 1),
#  ('EnglishRussianSpanishJapaneseCzech', 1),
#  ('(all', 1),
#  ('support)', 1),
#  ('(text', 1),
#  ('only)', 1),
#  ('[b]', 1),
#  ('German[b]', 1),
#  ('Spanish[b]', 1),
#  ('Russian[b]', 1)]

# %%
languages = ['English','German','French','Spanish','Italian','Russian','Japanese','Polish','Portuguese','Chinese',\
             'Dutch','Korean','Czech','Turkish','Swedish','Hungarian','Danish','Norwegian','Finnish','Ukrainian',\
             'Greek','Romanian','Arabic','Thai','Bulgarian','Slovakian']
for l in languages:
    data[l] = data['SupportedLanguages'].str.contains(l)
print(data[languages].head())
data.drop(columns='SupportedLanguages',inplace=True)
# Out:
#    English  German  French  Spanish  Italian  Russian  Japanese  Polish  \
# 0     True    True    True     True     True    False     False   False
# 1     True    True    True     True     True    False     False   False
# 2     True    True    True     True     True    False     False   False
# 3     True    True    True     True     True    False     False   False
# 4     True    True    True    False    False    False     False   False
#
#    Portuguese  Chinese  Dutch  Korean  Czech  Turkish  Swedish  Hungarian  \
# 0       False     True  False    True  False    False    False      False
# 1       False    False  False   False  False    False    False      False
# 2       False    False  False   False  False    False    False      False
# 3       False    False  False   False  False    False    False      False
# 4       False    False  False    True  False    False    False      False
#
#    Danish  Norwegian  Finnish  Ukrainian  Greek  Romanian  Arabic   Thai  \
# 0   False      False    False      False  False     False   False  False
# 1   False      False    False      False  False     False   False  False
# 2   False      False    False      False  False     False   False  False
# 3   False      False    False      False  False     False   False  False
# 4   False      False    False      False  False     False   False  False
#
#    Bulgarian  Slovakian
# 0      False      False
# 1      False      False
# 2      False      False
# 3      False      False
# 4      False      False

# %%
#What's the other currency
print(data['PriceCurrency'].unique())
#Do blank currencies only happen when price is 0?
print(data.loc[data['PriceCurrency']==' ']['PriceInitial'].unique())
print(data.loc[data['PriceCurrency']==' ']['PriceFinal'].unique())
#Yes, so this column doesn't add value - let's drop
data.drop(columns='PriceCurrency',inplace=True)
# Out:
# ['USD' ' ']
# [0.]
# [0.]

# %%
#save intermediate data file

print(data.shape)

data.to_csv('../data/interim/data_cleaned.csv')
# Out:
# (10294, 92)
